# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data=pd.read_csv("food_coded.csv")
data
# Out:
#        GPA  Gender  breakfast  calories_chicken  calories_day  calories_scone  \
# 0      2.4       2          1               430           NaN           315.0
# 1    3.654       1          1               610           3.0           420.0
# 2      3.3       1          1               720           4.0           420.0
# 3      3.2       1          1               430           3.0           420.0
# 4      3.5       1          1               720           2.0           420.0
# ..     ...     ...        ...               ...           ...             ...
# 120    3.5       1          1               610           4.0           420.0
# 121      3       1          1               265           2.0           315.0
# 122  3.882       1          1               720           NaN           420.0
# 123      3       2          1               720           4.0           420.0
# 124    3.9       1          1               430           NaN           315.0
#
# ...

# %%
pd.set_option('display.max_columns', None)

# %%
data
# Out:
#        GPA  Gender  breakfast  calories_chicken  calories_day  calories_scone  \
# 0      2.4       2          1               430           NaN           315.0
# 1    3.654       1          1               610           3.0           420.0
# 2      3.3       1          1               720           4.0           420.0
# 3      3.2       1          1               430           3.0           420.0
# 4      3.5       1          1               720           2.0           420.0
# ..     ...     ...        ...               ...           ...             ...
# 120    3.5       1          1               610           4.0           420.0
# 121      3       1          1               265           2.0           315.0
# 122  3.882       1          1               720           NaN           420.0
# 123      3       2          1               720           4.0           420.0
# 124    3.9       1          1               430           NaN           315.0
#
# ...

# %% [markdown]
# ### BASIC CHECKS

# %%
data.head()
# Out:
#      GPA  Gender  breakfast  calories_chicken  calories_day  calories_scone  \
# 0    2.4       2          1               430           NaN           315.0
# 1  3.654       1          1               610           3.0           420.0
# 2    3.3       1          1               720           4.0           420.0
# 3    3.2       1          1               430           3.0           420.0
# 4    3.5       1          1               720           2.0           420.0
#
#    coffee                      comfort_food        comfort_food_reasons  \
# 0       1                              none       we dont have comfort
# 1       2       chocolate, chips, ice cream        Stress, bored, anger
# 2       2   frozen yogurt, pizza, fast food             stress, sadness
# 3       2  Pizza, Mac and cheese, ice cream                     Boredom
# 4       2      Ice cream, chocolate, chips   Stress, boredom, cravings
#
#    comfort_food_reasons_coded  cook  comfort_food_reasons_coded.1  cuisine  \
# ...

# %%
data.tail()
# Out:
#        GPA  Gender  breakfast  calories_chicken  calories_day  calories_scone  \
# 120    3.5       1          1               610           4.0           420.0
# 121      3       1          1               265           2.0           315.0
# 122  3.882       1          1               720           NaN           420.0
# 123      3       2          1               720           4.0           420.0
# 124    3.9       1          1               430           NaN           315.0
#
#      coffee                             comfort_food  \
# 120       2  wine. mac and cheese, pizza, ice cream
# 121       2               Pizza / Wings / Cheesecake
# 122       1               rice, potato, seaweed soup
# 123       1             Mac n Cheese, Lasagna, Pizza
# 124       2             Chocolates, pizza, and Ritz.
#
#                               comfort_food_reasons  \
# 120                           boredom and sadness
# 121                Loneliness / Homesick / Sadness
# ...

# %%
data.describe()
# Out:
#            Gender   breakfast  calories_chicken  calories_day  calories_scone  \
# count  125.000000  125.000000        125.000000    106.000000      124.000000
# mean     1.392000    1.112000        577.320000      3.028302      505.241935
# std      0.490161    0.316636        131.214156      0.639308      230.840506
# min      1.000000    1.000000        265.000000      2.000000      315.000000
# 25%      1.000000    1.000000        430.000000      3.000000      420.000000
# 50%      1.000000    1.000000        610.000000      3.000000      420.000000
# 75%      2.000000    1.000000        720.000000      3.000000      420.000000
# max      2.000000    2.000000        720.000000      4.000000      980.000000
#
#           coffee  comfort_food_reasons_coded        cook  \
# count  125.00000                  106.000000  122.000000
# mean     1.75200                    2.698113    2.786885
# std      0.43359                    1.972042    1.038351
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125 entries, 0 to 124
# Data columns (total 61 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   GPA                           123 non-null    object
#  1   Gender                        125 non-null    int64
#  2   breakfast                     125 non-null    int64
#  3   calories_chicken              125 non-null    int64
#  4   calories_day                  106 non-null    float64
#  5   calories_scone                124 non-null    float64
#  6   coffee                        125 non-null    int64
#  7   comfort_food                  124 non-null    object
#  8   comfort_food_reasons          124 non-null    object
#  9   comfort_food_reasons_coded    106 non-null    float64
#  10  cook                          122 non-null    float64
#  11  comfort_food_reasons_coded.1  125 non-null    int64
# ...

# %%
data.shape
# Out:
# (125, 61)

# %%
data.columns
# Out:
# Index(['GPA', 'Gender', 'breakfast', 'calories_chicken', 'calories_day',
#        'calories_scone', 'coffee', 'comfort_food', 'comfort_food_reasons',
#        'comfort_food_reasons_coded', 'cook', 'comfort_food_reasons_coded.1',
#        'cuisine', 'diet_current', 'diet_current_coded', 'drink',
#        'eating_changes', 'eating_changes_coded', 'eating_changes_coded1',
#        'eating_out', 'employment', 'ethnic_food', 'exercise',
#        'father_education', 'father_profession', 'fav_cuisine',
#        'fav_cuisine_coded', 'fav_food', 'food_childhood', 'fries', 'fruit_day',
#        'grade_level', 'greek_food', 'healthy_feeling', 'healthy_meal',
#        'ideal_diet', 'ideal_diet_coded', 'income', 'indian_food',
#        'italian_food', 'life_rewarding', 'marital_status',
#        'meals_dinner_friend', 'mother_education', 'mother_profession',
#        'nutritional_check', 'on_off_campus', 'parents_cook', 'pay_meal_out',
# ...

# %%
# checking duplicated values
 
data.duplicated().sum()    # here there is no duplicates in our dataset
# Out:
# 0

# %%
import pandas as pd

# Set display options to show all rows and all columns
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# Check for missing values and display the count for all columns
missing_values_count = data.isnull().sum()
print(missing_values_count)
# Out:
# GPA                              2
# Gender                           0
# breakfast                        0
# calories_chicken                 0
# calories_day                    19
# calories_scone                   1
# coffee                           0
# comfort_food                     1
# comfort_food_reasons             1
# comfort_food_reasons_coded      19
# cook                             3
# comfort_food_reasons_coded.1     0
# cuisine                         17
# diet_current                     1
# diet_current_coded               0
# drink                            2
# eating_changes                   3
# eating_changes_coded             0
# eating_changes_coded1            0
# eating_out                       0
# employment                       9
# ethnic_food                      0
# exercise                        13
# father_education                 1
# father_profession                3
# fav_cuisine                      2
# fav_cuisine_coded                0
# ...

# %% [markdown]
# #### GPA

# %%
data.GPA.value_counts()
# Out:
# 3.5           13
# 3             11
# 3.2           10
# 3.7           10
# 3.3            9
# 3.4            9
# 3.6            7
# 3.9            7
# 3.8            6
# 2.8            5
# 4              4
# 3.1            3
# 2.9            2
# 3.83           2
# 2.6            2
# 2.4            1
# 3.79 bitch     1
# 3.73           1
# 2.71           1
# 3.92           1
# 3.68           1
# 3.75           1
# Unknown        1
# 3.77           1
# 3.63           1
# 3.67           1
# 3.89           1
# Personal       1
# 3.35           1
# 3.292          1
# 3.605          1
# 3.654          1
# 3.65           1
# 3.87           1
# 2.2            1
# 3.904          1
# 2.25           1
# 3.882          1
# Name: GPA, dtype: int64

# %%
#Histogram since it has Numerical value
data.GPA.hist()
# Out:
# <AxesSubplot:>

# %%
import numpy as np
import pandas as pd

# Assuming 'data' is your DataFrame containing GPA data
# Convert non-numeric values to NaN
data['GPA'] = pd.to_numeric(data['GPA'], errors='coerce')

# Drop NaN values from the GPA column
cleaned_data = data.dropna(subset=['GPA'], axis=0)

# %%
np.median(data.GPA.dropna(axis=0))
# Out:
# 3.5

# %%
data.loc[data['GPA'].isnull()==True,'GPA']=np.median(data.GPA.dropna(axis=0))

# %% [markdown]
# #### calories_day

# %%
data.calories_day.value_counts()
# Out:
# 3.0    63
# 4.0    23
# 2.0    20
# Name: calories_day, dtype: int64

# %%
#Histogram since it has Numerical value
data.calories_day.hist()
# Out:
# <AxesSubplot:>

# %%
np.median(data.calories_day.dropna(axis=0))
# Out:
# 3.0

# %%
data.loc[data['calories_day'].isnull()==True,'calories_day']=np.median(data.calories_day.dropna(axis=0))

# %% [markdown]
# #### calories_scone

# %%
data.calories_scone.value_counts()
# Out:
# 420.0    79
# 980.0    23
# 315.0    22
# Name: calories_scone, dtype: int64

# %%
data.calories_scone.hist()
# Out:
# <AxesSubplot:>

# %%
np.median(data.calories_scone.dropna(axis=0))
# Out:
# 420.0

# %%
data.loc[data['calories_scone'].isnull()==True,'calories_scone']=np.median(data.calories_scone.dropna(axis=0))

# %% [markdown]
# #### comfort_food

# %%
data.comfort_food.value_counts()
# Out:
# none                                                                                                 1
# Chips sweets popcorn                                                                                 1
# Chocolate, Chips, Ice cream, French Fires, Pizza                                                     1
# Macaroni and cheese, chicken noodle soup, pizza                                                      1
# chips, ice cream, fruit snacks                                                                       1
# carrots, plantain chips, almonds, popcorn                                                            1
# Little Debbie snacks, donuts, pizza                                                                  1
# pizza, pasta, mac and cheese                                                                         1
# Chinese food, moes, sponge candy, homemade lasagne                                                   1
# ...

# %%
data.comfort_food.hist()
# Out:
# <AxesSubplot:>
# ) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
from scipy.stats import mode

# Drop NaN values from the 'comfort_food' column
cleaned_comfort_food = data['comfort_food'].dropna()

# Check if there are any non-numeric values
if cleaned_comfort_food.dtype == 'object':
    # Handle non-numeric values
    mode_value = cleaned_comfort_food.mode()[0]
else:
    # Calculate the mode
    mode_value = mode(cleaned_comfort_food)[0][0]

# Replace missing values in 'comfort_food' with the mode
data.loc[data['comfort_food'].isnull(), 'comfort_food'] = mode_value

# %% [markdown]
# #### comfort_food_reasons

# %%
data.comfort_food_reasons.value_counts()
# Out:
# boredom                                                                                                                                      7
# sadness                                                                                                                                      3
# Boredom                                                                                                                                      3
# Boredom                                                                                                                                      3
# boredom, sadness                                                                                                                             2
# Stress, sadness, boredom                                                                                                                     2
# ...

# %%
data.comfort_food_reasons.hist()
# Out:
# <AxesSubplot:>

# %%
from scipy.stats import mode

# %%
# Drop NaN values from the 'comfort_food_reasons' column
cleaned_comfort_food_reasons = data['comfort_food_reasons'].dropna()

# Check if there are any non-numeric values
if cleaned_comfort_food_reasons.dtype == 'object':
    # Handle non-numeric values
    mode_value = cleaned_comfort_food_reasons.mode()[0]
else:
    # Calculate the mode
    mode_value = mode(cleaned_comfort_food_reasons)[0][0]

# Replace missing values in 'comfort_food_reasons' with the mode
data.loc[data['comfort_food_reasons'].isnull(), 'comfort_food_reasons'] = mode_value

# %% [markdown]
# #### comfort_food_reasons_coded

# %%
data.comfort_food_reasons_coded.value_counts()
# Out:
# 2.0    49
# 1.0    22
# 3.0    18
# 9.0     5
# 5.0     4
# 4.0     3
# 7.0     3
# 6.0     1
# 8.0     1
# Name: comfort_food_reasons_coded, dtype: int64

# %%
data.comfort_food_reasons_coded.hist()
# Out:
# <AxesSubplot:>

# %%
np.median(data.comfort_food_reasons_coded.dropna(axis=0))
# Out:
# 2.0

# %%
data.loc[data['comfort_food_reasons_coded'].isnull()==True,'comfort_food_reasons_coded']=np.median(data.calories_day.dropna(axis=0))

# %% [markdown]
# #### cook

# %%
data.cook.value_counts()
# Out:
# 3.0    49
# 2.0    34
# 4.0    18
# 1.0    13
# 5.0     8
# Name: cook, dtype: int64

# %%
data.cook.hist()
# Out:
# <AxesSubplot:>

# %%
np.median(data.cook.dropna(axis=0))
# Out:
# 3.0

# %%
data.loc[data['cook'].isnull()==True,'cook']=np.median(data.cook.dropna(axis=0))

# %% [markdown]
# #### cuisine

# %%
data.cuisine.value_counts()
# Out:
# 1.0    86
# 2.0    13
# 3.0     3
# 4.0     3
# 6.0     2
# 5.0     1
# Name: cuisine, dtype: int64

# %%
data.cuisine.hist()
# Out:
# <AxesSubplot:>

# %%
np.median(data.cuisine.dropna(axis=0))
# Out:
# 1.0

# %%
data.loc[data['cuisine'].isnull()==True,'cuisine']=np.median(data.cuisine.dropna(axis=0))

# %% [markdown]
# #### diet_current

# %%
data.diet_current.value_counts()
# Out:
# eat good and exercise                                                                                                                                                                                                                                                     1
# No diet. I eat what makes me feel good                                                                                                                                                                                                                                    1
# My diet consists of high levels of meats with some vegetables. Coexisting with varying levels of sugars                                                                                                                                                                   1
# ...

# %%
data.diet_current.hist()
# Out:
# <AxesSubplot:>

# %%
# Drop NaN values from the 'diet_current' column
cleaned_diet_current = data['diet_current'].dropna()

# Check if there are any non-numeric values
if cleaned_diet_current.dtype == 'object':
    # Handle non-numeric values
    mode_value = cleaned_diet_current.mode()[0]
else:
    # Calculate the mode
    mode_value = mode(cleaned_diet_current)[0][0]

# Replace missing values in 'diet_current' with the mode
data.loc[data['diet_current'].isnull(),'diet_current'] = mode_value

# %% [markdown]
# #### drink

# %%
data.drink.value_counts()
# Out:
# 2.0    69
# 1.0    54
# Name: drink, dtype: int64

# %%
data.drink.hist()
# Out:
# <AxesSubplot:>

# %%
np.median(data.drink.dropna(axis=0))
# Out:
# 2.0

# %%
data.loc[data['drink'].isnull()==True,'drink']=np.median(data.drink.dropna(axis=0))

# %% [markdown]
# #### eating_changes

# %%
data.eating_changes.value_counts()
# Out:
# none                                                                                                                                                                                                                                                                                                                              2
# Less fruits and veggies                                                                                                                                                                                                                                                                                                           1
# I eat alot of carbs and eat much more frequently                                                                                                                                                                                                                                                                                  1
# ...

# %%
data.eating_changes.hist()
# Out:
# <AxesSubplot:>

# %%
# Drop NaN values from the 'eating_changes' column
cleaned_eating_changes = data['eating_changes'].dropna()

# Check if there are any non-numeric values
if cleaned_eating_changes.dtype == 'object':
    # Handle non-numeric values
    mode_value = cleaned_eating_changes.mode()[0]
else:
    # Calculate the mode
    mode_value = mode(cleaned_eating_changes)[0][0]

# Replace missing values in 'eating_changes' with the mode
data.loc[data['eating_changes'].isnull(), 'eating_changes'] = mode_value

# %% [markdown]
# #### employment

# %%
data.employment.value_counts()
# Out:
# 2.0    60
# 3.0    54
# 1.0     2
# Name: employment, dtype: int64

# %%
data.employment.hist()
# Out:
# <AxesSubplot:>

# %%
np.median(data.employment.dropna(axis=0))
# Out:
# 2.0

# %%
data.loc[data['employment'].isnull()==True,'employment']=np.median(data.employment.dropna(axis=0))

# %% [markdown]
# #### exercise

# %%
data.exercise.value_counts()
# Out:
# 1.0    57
# 2.0    44
# 3.0    11
# Name: exercise, dtype: int64

# %%
data.exercise.hist()
# Out:
# <AxesSubplot:>

# %%
np.median(data.exercise.dropna(axis=0))
# Out:
# 1.0

# %%
data.loc[data['exercise'].isnull()==True,'exercise']=np.median(data.exercise.dropna(axis=0))

# %% [markdown]
# #### father_education

# %%
data.father_education.value_counts()
# Out:
# 4.0    46
# 2.0    34
# 5.0    28
# 3.0    12
# 1.0     4
# Name: father_education, dtype: int64

# %%
data.father_education.hist()
# Out:
# <AxesSubplot:>

# %%
np.median(data.father_education.dropna(axis=0))
# Out:
# 4.0

# %%
data.loc[data['father_education'].isnull()==True,'father_education']=np.median(data.father_education.dropna(axis=0))

# %% [markdown]
# #### father_profession

# %%
data.father_profession.value_counts()
# Out:
# Construction                         2
# business owner                       2
# Lawyer                               2
# Electrical Engineer                  2
# Dentist                              2
# Business Owner                       2
# Teacher                              2
# IT                                   2
# Retired - Bus Driver                 1
# Transportation                       1
# Dentist                              1
# Project manager                      1
# cross-guard                          1
# mechanic                             1
# Truck Driver                         1
# handyman                             1
# engineer                             1
# Service Technition                   1
# Solar Engineering                    1
# Realtor                              1
# Works for Kirila Fire                1
# Police Officer                       1
# Contract negotiations                1
# self employed                        1
# ...

# %%
data.father_profession.hist()
# Out:
# <AxesSubplot:>

# %%
from scipy.stats import mode

# Drop NaN values from the 'father_profession' column
cleaned_father_profession = data['father_profession'].dropna()

# Check if there are any non-numeric values
if cleaned_father_profession.dtype == 'object':
    # Handle non-numeric values
    mode_value = cleaned_father_profession.mode()[0]
else:
    # Calculate the mode
    mode_value = mode(cleaned_father_profession)[0][0]

# Replace missing values in 'father_profession' with the mode
data.loc[data['father_profession'].isnull(), 'father_profession'] = mode_value

# %% [markdown]
# #### fav_cuisine

# %%
data.fav_cuisine.value_counts()
# Out:
# Italian                                     22
# Italian                                     19
# italian                                      6
# Mexican                                      5
# Mexican                                      4
# American                                     3
# American                                     3
# Chinese                                      3
# Chinese                                      2
# italian                                      2
# Indian                                       2
# Asian                                        2
# Korean                                       2
# Thai                                         2
# Japanese                                     1
# Authentic Chinese and Vietnamese food        1
# Mexican cuisine                              1
# american                                     1
# Lean                                         1
# Asian                                        1
# ...

# %%
data.fav_cuisine.hist()
# Out:
# <AxesSubplot:>

# %%
# Drop NaN values from the 'fav_cuisine' column
cleaned_fav_cuisine = data['fav_cuisine'].dropna()

# Check if there are any non-numeric values
if cleaned_fav_cuisine.dtype == 'object':
    # Handle non-numeric values
    mode_value = cleaned_fav_cuisine.mode()[0]
else:
    # Calculate the mode
    mode_value = mode(cleaned_fav_cuisine)[0][0]

# Replace missing values in 'fav_cuisine' with the mode
data.loc[data['fav_cuisine'].isnull(), 'fav_cuisine'] = mode_value

# %% [markdown]
# #### fav_food

# %%
data.fav_food.value_counts()
# Out:
# 1.0    73
# 3.0    38
# 2.0    12
# Name: fav_food, dtype: int64

# %%
data.fav_food.hist()
# Out:
# <AxesSubplot:>

# %%
np.median(data.fav_food.dropna(axis=0))
# Out:
# 1.0

# %%
data.loc[data['fav_food'].isnull()==True,'fav_food']=np.median(data.fav_food.dropna(axis=0))

# %% [markdown]
# #### food_childhood

# %%
data.food_childhood.value_counts()
# Out:
# Pizza                                                                                          5
# Pasta                                                                                          2
# Chicken                                                                                        2
# pizza                                                                                          2
# Mac and cheese                                                                                 2
# Spaghetti                                                                                      2
# Steak                                                                                          2
# Pasta, breakfast for dinner, pizza                                                             1
# peanut butter and jelly, celery and peanut butter, hot pockets                                 1
# Quesadilla, chocolate, steak                                                                   1
# ...

# %%
data.food_childhood.hist()
# Out:
# <AxesSubplot:>

# %%
mode_value = data['food_childhood'].dropna().mode()[0]
from scipy.stats import mode

from scipy.stats import mode

# Drop NaN values from the 'food_childhood' column
cleaned_food_childhood = data['food_childhood'].dropna()

# Check if there are any non-numeric values
if cleaned_food_childhood.dtype == 'object':
    # Handle non-numeric values
    mode_value = cleaned_food_childhood.mode()[0]
else:
    # Calculate the mode
    mode_value = mode(cleaned_food_childhood)[0][0]

# Replace missing values in 'food_childhood' with the mode
data.loc[data['food_childhood'].isnull(), 'food_childhood'] = mode_value

# %% [markdown]
# #### fries

# %%
data.fries.value_counts()
# Out:
# 1    114
# 2     11
# Name: fries, dtype: int64

# %%
data.fries.hist()
# Out:
# <AxesSubplot:>

# %%
np.median(data.fries.dropna(axis=0))
# Out:
# 1.0

# %%
data.loc[data['fries'].isnull()==True,'fries']=np.median(data.fries.dropna(axis=0))

# %% [markdown]
# #### healthy_meal

# %%
data.healthy_meal.value_counts()
# Out:
# looks not oily                                                                                                                                            1
# All food groups                                                                                                                                           1
# Chicken Salad with Pita Chips                                                                                                                             1
# Very colorful and smaller portions of the unhealthy food with larger portions of vegetables                                                               1
# half a plate of protein, quarter of a plate of carbs and the other quarter fruits or veggies.                                                             1
# Healthy meal for me is a food rich in protein, fiber, some sort of carbohydrates                                                                          1
# ...

# %%
data.healthy_meal.hist()
# Out:
# <AxesSubplot:>

# %%
mode_value = data['healthy_meal'].dropna().mode()[0]
from scipy.stats import mode

# Drop NaN values from the 'comfort_food' column
cleaned_healthy_meal= data['healthy_meal'].dropna()

# Check if there are any non-numeric values
if cleaned_healthy_meal.dtype == 'object':
    # Handle non-numeric values
    mode_value = cleaned_healthy_meal.mode()[0]
else:
    # Calculate the mode
    mode_value = mode(cleaned_healthy_meal)[0][0]

# Replace missing values in 'healthy_meal' with the mode
data.loc[data['healthy_meal'].isnull(), 'healthy_meal'] = mode_value

# %% [markdown]
# #### ideal_diet

# %%
data.ideal_diet.value_counts()
# Out:
# being healthy                                                                                                                                                                                                                                                                                         1
# Whatever makes me feel good. Doesnt cost a fortune.                                                                                                                                                                                                                                                   1
# A balance between meats and vegetables with less sugar                                                                                                                                                                                                                                                1
# ...

# %%
data.ideal_diet.hist()
# Out:
# <AxesSubplot:>

# %%
# Drop NaN values from the 'ideal_diet' column
cleaned_ideal_diet = data['ideal_diet'].dropna()

# Check if there are any non-numeric values
if cleaned_ideal_diet.dtype == 'object':
    # Handle non-numeric values
    mode_value = cleaned_ideal_diet.mode()[0]
else:
    # Calculate the mode
    mode_value = mode(cleaned_ideal_diet)[0][0]

# Replace missing values in 'ideal_diet' with the mode
data.loc[data['ideal_diet'].isnull(), 'ideal_diet'] = mode_value

# %% [markdown]
# #### income

# %%
data.income.value_counts()
# Out:
# 6.0    41
# 5.0    33
# 4.0    20
# 3.0    17
# 2.0     7
# 1.0     6
# Name: income, dtype: int64

# %%
data.income.hist()
# Out:
# <AxesSubplot:>

# %%
np.median(data.income.dropna(axis=0))
# Out:
# 5.0

# %%
data.loc[data['income'].isnull()==True,'income']=np.median(data.income.dropna(axis=0))

# %% [markdown]
# #### life_rewarding

# %%
data.life_rewarding.value_counts()
# Out:
# 1.0     23
# 8.0     18
# 3.0     15
# 7.0     14
# 2.0     13
# 9.0     11
# 10.0    10
# 5.0     10
# 4.0      6
# 6.0      4
# Name: life_rewarding, dtype: int64

# %%
data.life_rewarding.hist()
# Out:
# <AxesSubplot:>

# %%
np.median(data.life_rewarding.dropna(axis=0))
# Out:
# 5.0

# %%
data.loc[data['life_rewarding'].isnull()==True,'life_rewarding']=np.median(data.life_rewarding.dropna(axis=0))

# %% [markdown]
# #### marital_status

# %%
data.marital_status.value_counts()
# Out:
# 1.0    64
# 2.0    59
# 4.0     1
# Name: marital_status, dtype: int64

# %%
data.marital_status.hist()
# Out:
# <AxesSubplot:>

# %%
np.median(data.marital_status.dropna(axis=0))
# Out:
# 1.0

# %%
data.loc[data['marital_status'].isnull()==True,'marital_status']=np.median(data.marital_status.dropna(axis=0))

# %% [markdown]
# #### meals_dinner_friend

# %%
data.meals_dinner_friend.value_counts()
# Out:
# Chicken, Steak, Pasta                                                                                                                                  2
# rice, chicken,  soup                                                                                                                                   1
# any Chinese food, pasta, burgers                                                                                                                       1
# Rice with vegetables, chicken with pasta, salad                                                                                                        1
# burritos, pasta, chicken                                                                                                                               1
# Pasta, pizza, and chicken                                                                                                                              1
# ...

# %%
data.meals_dinner_friend.hist()
# Out:
# <AxesSubplot:>
# ) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# Drop NaN values from the 'meals_dinner_friend' column
cleaned_meals_dinner_friend= data['meals_dinner_friend'].dropna()

# Check if there are any non-numeric values
if cleaned_meals_dinner_friend.dtype == 'object':
    # Handle non-numeric values
    mode_value = cleaned_meals_dinner_friend.mode()[0]
else:
    # Calculate the mode
    mode_value = mode(cleaned_meals_dinner_friend)[0][0]

# Replace missing values in 'meals_dinner_friend' with the mode
data.loc[data['meals_dinner_friend'].isnull(), 'meals_dinner_friend'] = mode_value

# %% [markdown]
# #### mother_education

# %%
data.mother_education.value_counts()
# Out:
# 4.0    46
# 2.0    30
# 5.0    23
# 3.0    18
# 1.0     5
# Name: mother_education, dtype: int64

# %%
data.mother_education.hist()
# Out:
# <AxesSubplot:>

# %%
np.median(data.mother_education.dropna(axis=0))
# Out:
# 4.0

# %%
data.loc[data['mother_education'].isnull()==True,'mother_education']=np.median(data.mother_education.dropna(axis=0))

# %% [markdown]
# #### mother_profession

# %%
data.mother_profession.value_counts()
# Out:
# Teacher                                             3
# Secretary                                           3
# unemployed                                          2
# Nurse                                               2
# Homemaker                                           2
# Banker                                              2
# teacher                                             2
# Accountant                                          2
# Respiratory Therapist                               2
# Health teacher                                      1
# Runs a Daycare                                      1
# works in Loans department in First National Bank    1
# secretary                                           1
# Legal Secretary                                     1
# none                                                1
# self employed                                       1
# Programs coordinator                                1
# ...

# %%
data.mother_profession.hist()
# Out:
# <AxesSubplot:>

# %%
# Drop NaN values from the 'mother_profession' column
cleaned_mother_profession= data['mother_profession'].dropna()

# Check if there are any non-numeric values
if cleaned_mother_profession.dtype == 'object':
    # Handle non-numeric values
    mode_value = cleaned_mother_profession.mode()[0]
else:
    # Calculate the mode
    mode_value = mode(cleaned_mother_profession)[0][0]

# Replace missing values in 'mother_profession' with the mode
data.loc[data['mother_profession'].isnull(), 'mother_profession'] = mode_value

# %% [markdown]
# #### on_off_campus

# %%
data.on_off_campus.value_counts()
# Out:
# 1.0    97
# 2.0    16
# 3.0     9
# 4.0     2
# Name: on_off_campus, dtype: int64

# %%
data.on_off_campus.hist()
# Out:
# <AxesSubplot:>

# %%
np.median(data.on_off_campus.dropna(axis=0))
# Out:
# 1.0

# %%
data.loc[data['on_off_campus'].isnull()==True,'on_off_campus']=np.median(data.on_off_campus.dropna(axis=0))

# %% [markdown]
# #### persian_food

# %%
data.persian_food.value_counts()
# Out:
# 1.0    30
# 3.0    29
# 2.0    26
# 5.0    23
# 4.0    16
# Name: persian_food, dtype: int64

# %%
data.persian_food.hist()
# Out:
# <AxesSubplot:>

# %%
np.median(data.persian_food.dropna(axis=0))
# Out:
# 3.0

# %%
data.loc[data['persian_food'].isnull()==True,'persian_food']=np.median(data.persian_food.dropna(axis=0))

# %% [markdown]
# #### self_perception_weight

# %%
data.self_perception_weight.value_counts()
# Out:
# 3.0    45
# 4.0    31
# 2.0    31
# 5.0     6
# 1.0     6
# 6.0     5
# Name: self_perception_weight, dtype: int64

# %%
data.self_perception_weight.hist()
# Out:
# <AxesSubplot:>

# %%
np.median(data.self_perception_weight.dropna(axis=0))
# Out:
# 3.0

# %%
data.loc[data['self_perception_weight'].isnull()==True,'self_perception_weight']=np.median(data.self_perception_weight.dropna(axis=0))

# %% [markdown]
# #### soup

# %%
data.soup.value_counts()
# Out:
# 1.0    97
# 2.0    27
# Name: soup, dtype: int64

# %%
data.soup.hist()
# Out:
# <AxesSubplot:>

# %%
np.median(data.soup.dropna(axis=0))
# Out:
# 1.0

# %%
data.loc[data['soup'].isnull()==True,'soup']=np.median(data.soup.dropna(axis=0))

# %% [markdown]
# #### sports

# %%
data.sports.value_counts()
# Out:
# 1.0    75
# 2.0    48
# Name: sports, dtype: int64

# %%
data.sports.hist()
# Out:
# <AxesSubplot:>

# %%
np.median(data.sports.dropna(axis=0))
# Out:
# 1.0

# %%
data.loc[data['sports'].isnull()==True,'sports']=np.median(data.sports.dropna(axis=0))

# %% [markdown]
# #### tortilla_calories

# %%
data.tortilla_calories.value_counts()
# Out:
# 1165.0    46
# 940.0     43
# 725.0     22
# 580.0     13
# Name: tortilla_calories, dtype: int64

# %%
data.tortilla_calories.hist()
# Out:
# <AxesSubplot:>

# %%
np.median(data.tortilla_calories.dropna(axis=0))
# Out:
# 940.0

# %%
data.loc[data['tortilla_calories'].isnull()==True,'tortilla_calories']=np.median(data.tortilla_calories.dropna(axis=0))

# %% [markdown]
# #### type_sports

# %%
data.type_sports.value_counts()
# Out:
# none                                                           8
# Hockey                                                         7
# None                                                           5
# softball                                                       4
# Soccer                                                         4
# Volleyball                                                     3
# soccer                                                         3
# Softball                                                       3
# field hockey                                                   2
# Lacrosse                                                       2
# Ice hockey                                                     2
# hockey                                                         2
# Wrestling                                                      2
# Tennis                                                         2
# ...

# %%
data.type_sports.hist()
# Out:
# <AxesSubplot:>

# %%
# Drop NaN values from the 'type_sports' column
cleaned_type_sports= data['type_sports'].dropna()

# Check if there are any non-numeric values
if cleaned_type_sports.dtype == 'object':
    # Handle non-numeric values
    mode_value = cleaned_type_sports.mode()[0]
else:
    # Calculate the mode
    mode_value = mode(cleaned_type_sports)[0][0]

# Replace missing values in 'type_sports' with the mode
data.loc[data['type_sports'].isnull(), 'type_sports'] = mode_value

# %% [markdown]
# #### weight

# %%
data.weight.value_counts()
# Out:
# 135                         8
# 140                         8
# 150                         7
# 170                         7
# 175                         6
# 180                         6
# 155                         6
# 185                         6
# 165                         5
# 190                         5
# 125                         5
# 145                         4
# 200                         4
# 130                         4
# 120                         3
# 160                         3
# 129                         2
# 113                         2
# 128                         2
# 167                         2
# 210                         2
# 118                         1
# 192                         1
# 187                         1
# 112                         1
# 144 lbs                     1
# 127                         1
# 260                         1
# 184                         1
# 230                         1
# 138                         1
# ...

# %%
data.weight.hist()
# Out:
# <AxesSubplot:>

# %%
data['weight'] = pd.to_numeric(data['weight'], errors='coerce')

# %%
cleaned_data = data.dropna(subset=['weight'], axis=0)

# %%
np.median(data.weight.dropna(axis=0))
# Out:
# 155.0

# %%
data.loc[data['weight'].isnull()==True,'weight']=np.median(data.weight.dropna(axis=0))

# %%
# Set display options to show all rows and all columns
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# Check for missing values and display the count for all columns
missing_values_count = data.isnull().sum()
print(missing_values_count)
# Out:
# GPA                             0
# Gender                          0
# breakfast                       0
# calories_chicken                0
# calories_day                    0
# calories_scone                  0
# coffee                          0
# comfort_food                    0
# comfort_food_reasons            0
# comfort_food_reasons_coded      0
# cook                            0
# comfort_food_reasons_coded.1    0
# cuisine                         0
# diet_current                    0
# diet_current_coded              0
# drink                           0
# eating_changes                  0
# eating_changes_coded            0
# eating_changes_coded1           0
# eating_out                      0
# employment                      0
# ethnic_food                     0
# exercise                        0
# father_education                0
# father_profession               0
# fav_cuisine                     0
# fav_cuisine_coded               0
# ...
